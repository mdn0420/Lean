# %%
import pytools.leantools as lt
import pandas as pd
import os

# %%
script_dir = os.path.abspath('') #<-- absolute dir the script is in
result_dir = os.path.join (script_dir, "../results/parallax/backtest2")
algo_result_filepath = os.path.join(result_dir, "USDCAD-H4.json")
analysis_data_filepath = os.path.join(result_dir, "USDCAD-H4-analysis_data.json")
SYMBOLS = ['EURUSD', 'USDJPY', 'USDCAD']
analysis_file_suffix = "-analysis_data"

# %%
stat_columns = ['TradeStats.TotalNumberOfTrades', 
             'TradeStats.ProfitLossRatio', 
             'PortfolioStats.AverageWinRate', 
             'PortfolioStats.AverageLossRate',
             'PortfolioStats.WinRate',
             'PortfolioStats.Drawdown',
            'PortfolioStats.TotalNetProfit']

def get_stats(symbols, timeframe):
    stats_list = []
    for s in symbols:
        name = f'{s}-{timeframe}'
        path = os.path.join(result_dir, f'{name}.json')
        stats = lt.get_trade_statistics(path)
        stats = stats[stat_columns]
        stats.rename(index={0:name}, inplace=True)
        stats_list.append(stats)

    result = pd.concat(stats_list)
    return result

# %% [markdown]
# https://stackoverflow.com/questions/38107304/pandas-changing-a-specific-row-to-percentages

# %%
# Get H4 stats
h4_stats = get_stats(SYMBOLS, "H4")
#h6_stats = get_stats(SYMBOLS, "H6")
d1_stats = get_stats(SYMBOLS, "D1")
all_stats = pd.concat([h4_stats, d1_stats])
#all_stats.style.format({
#        'PortfolioStats.WinRate' : '{:,.1%}'.format
#    })

def format_stats(stats_df):
    result = stats_df.transpose()
    result.loc['PortfolioStats.AverageWinRate'] = result.loc['PortfolioStats.AverageWinRate'].apply('{:,.1%}'.format)
    result.loc['PortfolioStats.AverageLossRate'] = result.loc['PortfolioStats.AverageLossRate'].apply('{:,.1%}'.format)
    result.loc['PortfolioStats.WinRate'] = result.loc['PortfolioStats.WinRate'].apply('{:,.1%}'.format)
    result.loc['PortfolioStats.Drawdown'] = result.loc['PortfolioStats.Drawdown'].apply('{:,.1%}'.format)
    result.loc['PortfolioStats.TotalNetProfit'] = result.loc['PortfolioStats.TotalNetProfit'].apply('{:,.1%}'.format)
    return result

all_stats = format_stats(all_stats)
all_stats
# Out:
#                                EURUSD-H4 USDJPY-H4 USDCAD-H4 EURUSD-H6  \
# TradeStats.TotalNumberOfTrades       121       117        95        80
# TradeStats.ProfitLossRatio        1.8134    1.8447    1.8667    1.8004
# PortfolioStats.AverageWinRate       1.6%      1.6%      1.7%      1.6%
# PortfolioStats.AverageLossRate     -0.9%     -0.9%     -0.9%     -0.9%
# PortfolioStats.WinRate             24.0%     29.9%     21.1%     26.2%
# PortfolioStats.Drawdown            31.3%     25.4%     31.8%     22.1%
# PortfolioStats.TotalNetProfit     -30.2%    -15.1%    -29.2%    -17.1%
#
#                                USDJPY-H6 USDCAD-H6 EURUSD-D1 USDJPY-D1  \
# TradeStats.TotalNumberOfTrades        97        71        18        21
# TradeStats.ProfitLossRatio        2.0806    2.1541    2.4751    2.4028
# PortfolioStats.AverageWinRate       1.8%      1.9%      1.9%      2.1%
# PortfolioStats.AverageLossRate     -0.8%     -0.9%     -0.8%     -0.9%
# PortfolioStats.WinRate             22.7%     32.4%     38.9%     19.1%
# PortfolioStats.Drawdown            23.3%     14.8%      5.7%      6.3%
# PortfolioStats.TotalNetProfit     -20.6%      1.5%      4.7%     -6.2%
#
#                                USDCAD-D1
# TradeStats.TotalNumberOfTrades        20
# TradeStats.ProfitLossRatio        1.9677
# PortfolioStats.AverageWinRate       1.7%
# PortfolioStats.AverageLossRate     -0.8%
# PortfolioStats.WinRate             40.0%
# PortfolioStats.Drawdown             3.6%
# PortfolioStats.TotalNetProfit       3.2%

# %%
bar_data_df = lt.get_bar_data_df(analysis_data_filepath)
#bar_data_df

# %%
closed_trades = lt.get_closed_trades_df(algo_result_filepath).drop(columns=['Direction', 'TotalFees', 'MAE', 'MFE', 'Symbol.ID', 'Symbol.Permtick'])
#closed_trades

# %% [markdown]
# Grab the trade signals

# %%
trade_setups_df = lt.get_trade_setups_df(analysis_data_filepath)
#trade_setups_df

# %%
merged_trade_data = trade_setups_df.join(closed_trades, on='tradeIndex')
merged_trade_data
# Out:
#                            symbol direction  slPips  tpPips  plPips  \
# BarTime
# 2016-01-12 10:00:00+00:00  USDCAD      Sell    29.8   100.4   -30.5
# 2016-02-03 06:00:00+00:00  USDCAD      Sell    44.1   148.8   148.8
# 2016-02-04 14:00:00+00:00  USDCAD       Buy    46.2   156.1    52.0
# 2016-02-11 14:00:00+00:00  USDCAD      Sell    33.9   167.7   -34.1
# 2016-02-18 06:00:00+00:00  USDCAD       Buy    21.0    70.8   -21.2
# ...                           ...       ...     ...     ...     ...
# 2019-11-07 06:00:00+00:00  USDCAD      Sell    20.0    67.1   -20.0
# 2019-11-18 10:00:00+00:00  USDCAD       Buy     9.2    45.2    -9.5
# 2019-11-27 14:00:00+00:00  USDCAD       Buy    14.4    48.4    16.0
# 2019-12-12 10:00:00+00:00  USDCAD       Buy     9.5    31.9    -0.4
# 2019-12-19 02:00:00+00:00  USDCAD       Buy     2.9     9.7    -2.9
#
#                            tradeIndex             EntryTime  EntryPrice  \
# BarTime
# 2016-01-12 10:00:00+00:00           0  2016-01-12T14:06:00Z     1.41894
# 2016-02-03 06:00:00+00:00           1  2016-02-03T10:09:00Z     1.40293
# 2016-02-04 14:00:00+00:00           2  2016-02-05T09:46:00Z     1.37137
# 2016-02-11 14:00:00+00:00           3  2016-02-11T18:01:00Z     1.39509
# 2016-02-18 06:00:00+00:00           4  2016-02-18T10:03:00Z     1.36874
# ...                               ...                   ...         ...
# 2019-11-07 06:00:00+00:00          90  2019-11-07T11:57:00Z     1.31690
# 2019-11-18 10:00:00+00:00          91  2019-11-18T14:14:00Z     1.32269
# 2019-11-27 14:00:00+00:00          92  2019-11-27T18:04:00Z     1.32836
# 2019-12-12 10:00:00+00:00          93  2019-12-12T14:37:00Z     1.31812
# 2019-12-19 02:00:00+00:00          94  2019-12-19T06:06:00Z     1.31185
#
#                             Quantity              ExitTime  ExitPrice  \
# BarTime
# 2016-01-12 10:00:00+00:00   475973.0  2016-01-12T14:34:00Z    1.42199
# 2016-02-03 06:00:00+00:00   314761.0  2016-02-03T13:29:00Z    1.38805
# 2016-02-04 14:00:00+00:00   304091.0  2016-02-05T13:34:00Z    1.37657
# 2016-02-11 14:00:00+00:00   425718.0  2016-02-11T19:19:00Z    1.39850
# 2016-02-18 06:00:00+00:00   667900.0  2016-02-18T11:13:00Z    1.36662
# ...                              ...                   ...        ...
# 2019-11-07 06:00:00+00:00   477953.0  2019-11-07T16:47:00Z    1.31890
# 2019-11-18 10:00:00+00:00  1035813.0  2019-11-18T15:48:00Z    1.32174
# 2019-11-27 14:00:00+00:00   658745.0  2019-11-29T13:24:00Z    1.32996
# 2019-12-12 10:00:00+00:00   998971.0  2019-12-12T17:08:00Z    1.31808
# 2019-12-19 02:00:00+00:00  3249011.0  2019-12-19T06:08:00Z    1.31156
#
#                            ProfitLoss    Duration  EndTradeDrawdown  \
# BarTime
# 2016-01-12 10:00:00+00:00    -1020.98    00:28:00          -1148.18
# 2016-02-03 06:00:00+00:00     3374.52    03:20:00            -23.81
# 2016-02-04 14:00:00+00:00     1148.40    03:48:00           -649.28
# 2016-02-11 14:00:00+00:00    -1038.12    01:18:00          -1615.03
# 2016-02-18 06:00:00+00:00    -1036.01    01:10:00          -1532.02
# ...                               ...         ...               ...
# 2019-11-07 06:00:00+00:00     -724.83    04:50:00           -965.84
# 2019-11-18 10:00:00+00:00     -744.45    01:34:00           -920.77
# 2019-11-27 14:00:00+00:00      792.45  1.19:20:00           -423.46
# 2019-12-12 10:00:00+00:00      -30.31    02:31:00           -871.52
# 2019-12-19 02:00:00+00:00     -718.31    00:02:00           -718.31
#
#                           Symbol.Value
# BarTime
# 2016-01-12 10:00:00+00:00       USDCAD
# 2016-02-03 06:00:00+00:00       USDCAD
# 2016-02-04 14:00:00+00:00       USDCAD
# 2016-02-11 14:00:00+00:00       USDCAD
# 2016-02-18 06:00:00+00:00       USDCAD
# ...                                ...
# 2019-11-07 06:00:00+00:00       USDCAD
# 2019-11-18 10:00:00+00:00       USDCAD
# 2019-11-27 14:00:00+00:00       USDCAD
# 2019-12-12 10:00:00+00:00       USDCAD
# 2019-12-19 02:00:00+00:00       USDCAD
#
# [117 rows x 15 columns]

# %%
#bar_data_df.join(trade_setups_df)

# %% [markdown]
# https://pandas.pydata.org/docs/user_guide/merging.html#timeseries-friendly-merging

# %%
merged_setups = pd.merge_asof(merged_trade_data, bar_data_df, left_on='BarTime', right_on='Time', direction='nearest')
merged_setups
# Out:
#      symbol direction  slPips  tpPips  plPips  tradeIndex  \
# 0    USDCAD      Sell    29.8   100.4   -30.5           0
# 1    USDCAD      Sell    44.1   148.8   148.8           1
# 2    USDCAD       Buy    46.2   156.1    52.0           2
# 3    USDCAD      Sell    33.9   167.7   -34.1           3
# 4    USDCAD       Buy    21.0    70.8   -21.2           4
# ..      ...       ...     ...     ...     ...         ...
# 112  USDCAD      Sell    20.0    67.1   -20.0          90
# 113  USDCAD       Buy     9.2    45.2    -9.5          91
# 114  USDCAD       Buy    14.4    48.4    16.0          92
# 115  USDCAD       Buy     9.5    31.9    -0.4          93
# 116  USDCAD       Buy     2.9     9.7    -2.9          94
#
#                 EntryTime  EntryPrice   Quantity              ExitTime  ...  \
# 0    2016-01-12T14:06:00Z     1.41894   475973.0  2016-01-12T14:34:00Z  ...
# 1    2016-02-03T10:09:00Z     1.40293   314761.0  2016-02-03T13:29:00Z  ...
# 2    2016-02-05T09:46:00Z     1.37137   304091.0  2016-02-05T13:34:00Z  ...
# 3    2016-02-11T18:01:00Z     1.39509   425718.0  2016-02-11T19:19:00Z  ...
# 4    2016-02-18T10:03:00Z     1.36874   667900.0  2016-02-18T11:13:00Z  ...
# ..                    ...         ...        ...                   ...  ...
# 112  2019-11-07T11:57:00Z     1.31690   477953.0  2019-11-07T16:47:00Z  ...
# 113  2019-11-18T14:14:00Z     1.32269  1035813.0  2019-11-18T15:48:00Z  ...
# 114  2019-11-27T18:04:00Z     1.32836   658745.0  2019-11-29T13:24:00Z  ...
# 115  2019-12-12T14:37:00Z     1.31812   998971.0  2019-12-12T17:08:00Z  ...
# 116  2019-12-19T06:06:00Z     1.31185  3249011.0  2019-12-19T06:08:00Z  ...
#
#      BBUpper  BBLower   StochK   StochD atrPips         O         H         L  \
# 0     1.4260   1.4029  77.9381  84.1087    56.3  1.422370  1.423080  1.417665
# 1     1.4096   1.3949  83.1147  82.3171    64.4  1.408610  1.409060  1.401035
# 2     1.4199   1.3646   9.0312   7.6435    71.7  1.367440  1.373360  1.364945
# 3     1.3995   1.3844  81.9554  81.0958    71.5  1.398610  1.400275  1.391890
# 4     1.3929   1.3649   6.3087   4.3500    54.1  1.366025  1.369640  1.365820
# ..       ...      ...      ...      ...     ...       ...       ...       ...
# 112   1.3196   1.3122  83.3210  89.6832    18.7  1.319210  1.319670  1.316050
# 113   1.3274   1.3210  17.0605  10.0597    16.5  1.321685  1.323550  1.321290
# 114   1.3322   1.3259  18.0401  15.8847    17.9  1.326695  1.328975  1.326365
# 115   1.3279   1.3158  14.3211   9.4141    17.1  1.317120  1.318525  1.316805
# 116   1.3192   1.3106  16.6869  17.1017    20.7  1.311550  1.311975  1.311450
#
#             C  spread
# 0    1.418400     2.8
# 1    1.402615     2.5
# 2    1.372585     1.9
# 3    1.395055     2.7
# 4    1.368975     2.5
# ..        ...     ...
# 112  1.316335     1.5
# 113  1.322935     1.7
# 114  1.328420     1.8
# 115  1.318310     1.6
# 116  1.311900     1.6
#
# [117 rows x 26 columns]

# %%
#merged_closed_trades = merged_setups
winning_trades = merged_setups[(merged_setups['plPips'] > 0) & (merged_setups['tradeIndex'] >= 0)]
losing_trades = merged_setups[(merged_setups['plPips'] <= 0) & (merged_setups['tradeIndex'] >= 0)]
describeColumns = ['slPips', 'tpPips', 'atrPips', 'spread']
winning_trades_desc = winning_trades.describe()[describeColumns]
losing_trades_desc = losing_trades.describe()[describeColumns]

winning_trades_desc
# Out:
#           slPips      tpPips    atrPips     spread
# count  20.000000   20.000000  20.000000  20.000000
# mean   20.215000   74.030000  35.645000   1.995000
# std    11.386154   38.122836  13.449495   0.660522
# min     7.800000   26.100000  17.900000   1.400000
# 25%    12.675000   45.275000  26.800000   1.600000
# 50%    16.950000   63.300000  33.700000   1.800000
# 75%    25.100000   98.100000  39.975000   2.125000
# max    46.200000  156.100000  71.700000   4.500000

# %%
losing_trades_desc
# Out:
#           slPips      tpPips    atrPips     spread
# count  75.000000   75.000000  75.000000  75.000000
# mean   19.176000   75.508000  33.065333   2.557333
# std    10.984889   41.766609  10.564519   1.989987
# min     2.900000    9.700000  16.500000   1.400000
# 25%    10.200000   44.100000  26.150000   1.600000
# 50%    17.100000   64.800000  31.600000   1.800000
# 75%    24.600000  100.350000  37.250000   2.500000
# max    55.800000  187.900000  71.500000  11.000000

# %%
merged_setups.describe()
# Out:
#            slPips      tpPips      plPips  tradeIndex  EntryPrice  \
# count  117.000000  117.000000  117.000000  117.000000   95.000000
# mean    20.001709   75.623077   -4.800855   37.974359    1.311177
# std     11.156852   40.344556   26.932228   31.155467    0.035227
# min      2.900000    9.700000  -50.200000   -1.000000    1.235810
# 25%     11.300000   45.200000  -19.800000    7.000000    1.292940
# 50%     17.800000   66.600000   -8.400000   36.000000    1.314780
# 75%     26.900000   99.900000    0.000000   65.000000    1.332010
# max     59.300000  199.700000  148.800000   94.000000    1.418940
#
#            Quantity  ExitPrice   ProfitLoss  EndTradeDrawdown       BBMid  \
# count  9.500000e+01  95.000000    95.000000         95.000000  117.000000
# mean   7.699300e+05   1.310932  -307.886947      -1131.866842    1.311597
# std    4.401622e+05   0.035449  1026.662346        519.395199    0.034538
# min    1.996440e+05   1.233830 -1593.780000      -2539.270000    1.232900
# 25%    4.599550e+05   1.292100  -930.485000      -1492.210000    1.291900
# 50%    6.679000e+05   1.313780  -783.850000      -1076.890000    1.315000
# 75%    1.029104e+06   1.331690   -14.855000       -787.125000    1.331700
# max    3.249011e+06   1.421990  3594.090000        -23.810000    1.414500
#
#           BBUpper     BBLower      StochK      StochD     atrPips           O  \
# count  117.000000  117.000000  117.000000  117.000000  117.000000  117.000000
# mean     1.319514    1.303685   44.933865   45.202174   33.976068    1.310802
# std      0.034879    0.034650   34.588505   37.243885   11.305306    0.034186
# min      1.243200    1.222500    5.845300    4.350000   16.500000    1.233615
# 25%      1.299100    1.282400   13.888900   11.045100   26.100000    1.294640
# 50%      1.321800    1.307400   21.729200   17.933500   32.600000    1.314115
# 75%      1.339600    1.326800   81.010000   84.690600   39.200000    1.330370
# max      1.426000    1.402900   95.022500   95.427600   71.700000    1.422370
#
#                 H           L           C      spread
# count  117.000000  117.000000  117.000000  117.000000
# mean     1.312888    1.308911    1.310770    2.336752
# std      0.033985    0.033916    0.033780    1.648332
# min      1.236640    1.233105    1.236440    1.400000
# 25%      1.296340    1.292415    1.292965    1.600000
# 50%      1.316395    1.313180    1.315090    1.800000
# 75%      1.332930    1.329110    1.331795    2.300000
# max      1.423080    1.417665    1.418400   11.000000
